# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('ToneAnalyzer.csv')

# %%
df.head()
# Out:
#    Unnamed: 0    usernameTweet  \
# 0           0  Naveens27368191
# 1           1       wenagrutas
# 2           2      YouthSefton
# 3           3     DemuxAcademy
# 4           4        perezlevi
#
#                                                 text  nbr_retweet  \
# 0   DIPR COVID19  KarnatakaDIPR  MigrantKA    I h...            0
# 1  Oh  They deserve it because are working hard a...            1
# 2  Everyone is going to find the current Covid19 ...            7
# 3  Do you always tend to get clumsy in an awkward...            1
# 4  Of course time slot matters but substitutes le...            0
#
#    nbr_favorite  nbr_reply             datetime  is_reply  is_retweet  joy  \
# 0             1          2  2020-05-06 14:58:38     False       False  NaN
# 1             3          0  2020-05-27 17:22:38      True       False  1.0
# 2             4          0  2020-06-11 17:06:08     False       False  NaN
# ...

# %%
sum((df.joy))
# Out:
# nan

# %%
import math
import numpy as np

# %%
math.isnan(df.joy[0])
# Out:
# True

# %%
df = df.replace(to_replace =np.nan, 
                 value =False)
df = df.replace(to_replace =1, 
                 value =True)

# %%
df.head()
# Out:
#   Unnamed: 0    usernameTweet  \
# 0          0  Naveens27368191
# 1       True       wenagrutas
# 2          2      YouthSefton
# 3          3     DemuxAcademy
# 4          4        perezlevi
#
#                                                 text nbr_retweet nbr_favorite  \
# 0   DIPR COVID19  KarnatakaDIPR  MigrantKA    I h...           0         True
# 1  Oh  They deserve it because are working hard a...        True            3
# 2  Everyone is going to find the current Covid19 ...           7            4
# 3  Do you always tend to get clumsy in an awkward...        True            0
# 4  Of course time slot matters but substitutes le...           0            0
#
#   nbr_reply             datetime  is_reply  is_retweet    joy  analytical  \
# 0         2  2020-05-06 14:58:38     False       False  False       False
# 1         0  2020-05-27 17:22:38      True       False   True       False
# 2         0  2020-06-11 17:06:08     False       False  False       False
# ...

# %%
# for i in range(0,df.shape[0]):
#     if(df.joy[i] & df.analytical[i] & df.sadness[i] & df.confident[i] & df.tentative[i] & df.fear[i] & df.anger[i] ==True):
#         df=df.drop(df.index[i],axis=0)

# %%
Emotions = {'Joy':sum(df.joy),
            'Analytical':sum(df.analytical),
            'Sadness':sum(df.sadness),
            'Confident':sum(df.confident),
            'Tentative':sum(df.tentative),
            'Fear':sum(df.fear),
            'Anger':sum(df.anger),
            'Unemotional':df.shape[0]-sum(df.joy)-sum(df.analytical)-sum(df.sadness)
            -sum(df.confident)-sum(df.tentative)-sum(df.fear)-sum(df.anger)
           }

# %%
emotions=pd.DataFrame(list(Emotions.items()),columns = ['Emotions','Count'])

# %%
emotions
# Out:
#       Emotions  Count
# 0          Joy   1241
# 1   Analytical   2637
# 2      Sadness   1322
# 3    Confident    491
# 4    Tentative    629
# 5         Fear    171
# 6        Anger    150
# 7  Unemotional   2060

# %%
for i in range(0,emotions.shape[0]):
    emotions['Percentage'] = emotions['Count'].apply(lambda x: x/df.shape[0]*100)

# %%
emotions
# Out:
#       Emotions  Count  Percentage
# 0          Joy   1241   14.262728
# 1   Analytical   2637   30.306861
# 2      Sadness   1322   15.193656
# 3    Confident    491    5.643030
# 4    Tentative    629    7.229054
# 5         Fear    171    1.965291
# 6        Anger    150    1.723940
# 7  Unemotional   2060   23.675440

# %%
plt.figure(figsize=(13,5))
plt.barh(emotions.Emotions, emotions.Percentage,color=['darkorange', 'lightcoral', 'olivedrab', 'green', 'cyan', 'red','maroon','silver'])
plt.xlabel('Percentage %',fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.title('Public Emotions',fontsize=18)
for index, value in enumerate(round(emotions.Percentage,2)):
    plt.text(value, index, str(value),fontsize=11)
plt.savefig('Public Emotions.jpg')

# %%
df = df.replace(to_replace =True, 
                 value =1.0)

# %%
plt.plot(df.anger,df.datetime,kind='kde')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-222-78092d7eaaa1> in <module>
# ----> 1 plt.plot(df.anger,df.datetime,kind='kde')
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2794     return gca().plot(
#    2795         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2796         is not None else {}), **kwargs)
#    2797
#    2798
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1663         """
#    1664         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D._alias_map)
# -> 1665         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1666         for line in lines:
#    1667             self.add_line(line)
#
# ...

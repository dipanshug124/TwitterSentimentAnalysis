# %%
cd ..
# Out:
# C:\Users\fcc\Desktop\git_tweet\SBSPS-Challenge-2598-Twitter-Sentiment-Analysis

# %%
#importing libraries
import pandas as pd
import numpy as np
import string
import re
import nltk
from textblob import TextBlob
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from PolaritySubjectivity import *

# %%
df=pd.read_csv('covidtweets.csv')
pd.set_option('display.max_colwidth', 100)
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1    usernameTweet            ID  \
# 0           0             0        rj_ashwin  1.243960e+18
# 1           1             1    vikramsoni232  1.244163e+18
# 2           2             2  ABHISHE33329022  1.244291e+18
# 3           3             3  hindust74474485  1.253172e+18
# 4           4             4  KumarSa61420257  1.254602e+18
#
#                                                                                                   text  \
# 0  Sabse Pehle toh  Majdur ,  Labour  Class, Worker,kehna band Karo Unhe Tum Kya ho jo 'Work from h...
# 1  @ TajinderBagga   Bhaiya  i  proud of you. You are real hero in delhi in #lockdown21  You moral ...
# 2  Mam  India  mein hum ko company's ki audit krni chiye.wo  labour  ko pay kre lock down ki salary...
# 3  Videsh me rahne wale Bhai  India  laye Gaye but Jo log  India  me hi dusre state me fase huye h ...
# 4  Akhir bhojh ban gaye na bihari pure  India  pe. Students bhi and  Labour  bhi.Jab bihari  majdur...
#
#                                            url  nbr_retweet  nbr_favorite  \
# 0        /rj_ashwin/status/1243959777266286593            0             1
# 1    /vikramsoni232/status/1244163016012075008            0             0
# 2  /ABHISHE33329022/status/1244290847236972544            0             0
# 3  /hindust74474485/status/1253171675081904129            0             0
# 4  /KumarSa61420257/status/1254602420426063872            0             0
#
#    nbr_reply             datetime  is_reply  is_retweet       user_id  \
# 0          0  2020-03-28 23:24:57     False       False  2.898097e+09
# 1          0  2020-03-29 12:52:33     False       False  2.915966e+08
# 2          0  2020-03-29 21:20:30      True       False  1.244170e+18
# 3          0  2020-04-23 09:29:44     False       False  1.252877e+18
# 4          0  2020-04-27 08:15:01     False       False  9.912317e+17
#
#   has_media medias  Unnamed: 14  Unnamed: 15
# 0       NaN    NaN          NaN          NaN
# 1       NaN    NaN          NaN          NaN
# 2       NaN    NaN          NaN          NaN
# 3       NaN    NaN          NaN          NaN
# 4       NaN    NaN          NaN          NaN

# %%
# Dropping unnecessary columns

df_clean = df.drop(['Unnamed: 0','Unnamed: 14','Unnamed: 15','medias','has_media','user_id','url','ID'], axis=1)
df_clean.rename(columns={'text':'Tweets'}, inplace=True)
print(df_clean.shape)
df_clean.head()
# Out:
# (74553, 9)
#    Unnamed: 0.1    usernameTweet  \
# 0             0        rj_ashwin
# 1             1    vikramsoni232
# 2             2  ABHISHE33329022
# 3             3  hindust74474485
# 4             4  KumarSa61420257
#
#                                                                                                 Tweets  \
# 0  Sabse Pehle toh  Majdur ,  Labour  Class, Worker,kehna band Karo Unhe Tum Kya ho jo 'Work from h...
# 1  @ TajinderBagga   Bhaiya  i  proud of you. You are real hero in delhi in #lockdown21  You moral ...
# 2  Mam  India  mein hum ko company's ki audit krni chiye.wo  labour  ko pay kre lock down ki salary...
# 3  Videsh me rahne wale Bhai  India  laye Gaye but Jo log  India  me hi dusre state me fase huye h ...
# 4  Akhir bhojh ban gaye na bihari pure  India  pe. Students bhi and  Labour  bhi.Jab bihari  majdur...
#
#    nbr_retweet  nbr_favorite  nbr_reply             datetime  is_reply  \
# 0            0             1          0  2020-03-28 23:24:57     False
# 1            0             0          0  2020-03-29 12:52:33     False
# 2            0             0          0  2020-03-29 21:20:30      True
# 3            0             0          0  2020-04-23 09:29:44     False
# 4            0             0          0  2020-04-27 08:15:01     False
#
#    is_retweet
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False

# %%
df_clean['Subjectivity'] = df_clean['Tweets'].apply(getSubjectivity)
df_clean['Polarity'] = df_clean['Tweets'].apply(getPolarity)
df_clean['Analysis'] = df_clean['Polarity'].apply(getAnalysis)

# %%
dataStore = pd.DataFrame()
dataStore['Datetime'] = df_clean['datetime']
dataStore['Tweets'] =df_clean['Tweets']
dataStore['Subjectivity'] = df_clean['Subjectivity']
dataStore['Polarity'] = df_clean['Polarity']
dataStore['Analysis'] = df_clean['Analysis']
dataStore.head()
# Out:
#               Datetime  \
# 0  2020-03-28 23:24:57
# 1  2020-03-29 12:52:33
# 2  2020-03-29 21:20:30
# 3  2020-04-23 09:29:44
# 4  2020-04-27 08:15:01
#
#                                                                                                 Tweets  \
# 0  Sabse Pehle toh  Majdur ,  Labour  Class, Worker,kehna band Karo Unhe Tum Kya ho jo 'Work from h...
# 1  @ TajinderBagga   Bhaiya  i  proud of you. You are real hero in delhi in #lockdown21  You moral ...
# 2  Mam  India  mein hum ko company's ki audit krni chiye.wo  labour  ko pay kre lock down ki salary...
# 3  Videsh me rahne wale Bhai  India  laye Gaye but Jo log  India  me hi dusre state me fase huye h ...
# 4  Akhir bhojh ban gaye na bihari pure  India  pe. Students bhi and  Labour  bhi.Jab bihari  majdur...
#
#    Subjectivity  Polarity  Analysis
# 0      0.000000  0.000000   Neutral
# 1      0.404167  0.258333  Positive
# 2      0.288889 -0.155556  Negative
# 3      0.000000  0.000000   Neutral
# 4      0.500000  0.214286  Positive

# %%
dataStore.to_csv('PolaritySubjectivity.csv')

# %%
p_tweets = df_clean[df_clean['Analysis']=='Positive']
p_tweets_per = round(p_tweets.shape[0]/df_clean.shape[0] * 100, 3)

n_tweets = df_clean[df_clean['Analysis']=='Negative']
n_tweets_per = round(n_tweets.shape[0]/df_clean.shape[0] * 100, 3)

# %%
# # I have created the graph below using Tableau, but it can be also done using matplotlib here


# # Plot the polarity and subjectivity

# plt.figure(figsize = (20,20))
# plt.scatter(df_clean['Polarity'], df_clean['Subjectivity'], color='Blue')

# plt.title('Scatter Plot',fontsize = 40,fontweight='bold')
# plt.xlabel('Polarity',fontsize = 30)
# plt.ylabel('Subjectivity',fontsize =30)
# plt.xticks(fontsize=17)
# plt.yticks(fontsize=17)
# plt.savefig('Polarity vs Subjectivity (Scatter Plot)',dpi=300)
# plt.show()

# %%
# # Plot analysis count
# plt.title('Bar Plot')
# plt.xlabel('Sentiments')
# plt.ylabel('Count')
# df_clean['Analysis'].value_counts().plot(kind='bar')
# plt.savefig('Polarity vs Subjectivity (Bar Plot)',dpi=300)
# plt.show()
